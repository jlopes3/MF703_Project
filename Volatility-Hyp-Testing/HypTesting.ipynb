# %%
from scipy import stats
import pandas as pd
import numpy as np

# %%
def vol_difference_test(months_before, months_after, dataset):
    """ 
    This function analyzes daily returns in specified election and non-election periods,
    computes annualized volatilities for both, and performs Levene's test to assess 
    variance differences.

    Args:
        months_before (integer): the number of months before an election to start an election period
        months_after (integer): the number of months after an election to end an election period
        dataset (string): the filepath of the dataset
        
    Returns:
        annualized_election_volatility (float): the annualized volatility of election periods
        annualized_non_election_volatility (float): the annualized volatility of non-election periods
        lev_stat (float): the Levene statistic for the daily returns of the non-election periods and election periods
        p_value (float): the p-value from the Levene test
    """
    # Load historical data
    data = pd.read_csv(dataset)
    data['Date'] = pd.to_datetime(data['Date'])
    data.set_index('Date', inplace=True)
    data = data[(data.index >= '1974-01-01') & (data.index <= '2023-12-31')]

    # Calculate daily returns
    data['Daily Return'] = data['Adj Close'].pct_change()
    data = data.dropna(subset=['Daily Return'])

    # Separate data into election periods and non-election periods
    election_dates = [pd.Timestamp("1976-11-02"), pd.Timestamp("1980-11-04"), pd.Timestamp("1984-11-06"), pd.Timestamp("1988-11-08"), pd.Timestamp("1992-11-03"), pd.Timestamp("1996-11-05"), pd.Timestamp("2000-11-07"), pd.Timestamp("2004-11-02"), pd.Timestamp("2008-11-04"), pd.Timestamp("2012-11-06"), pd.Timestamp("2016-11-08"), pd.Timestamp("2020-11-03")]
    election_periods = [(day - pd.DateOffset(months=months_before), day + pd.DateOffset(months=months_after)) for day in election_dates]
    data['In Election Cycle'] = data.index.to_series().apply(
        lambda date: any(start <= date <= end for start, end in election_periods)
    )
    election_data = data[data['In Election Cycle']]
    non_election_data = data[~data['In Election Cycle']]

    # Calculate volatility
    election_volatility = election_data['Daily Return'].std()
    non_election_volatility = non_election_data['Daily Return'].std()

    # Annualize the volatility assuming 252 trading days per year
    annualized_election_volatility = election_volatility * np.sqrt(252)
    annualized_non_election_volatility = non_election_volatility * np.sqrt(252)

    # Levene's Test to see if the variances of Daily Returns are equal
    lev_stat, p_value = stats.levene(election_data['Daily Return'], non_election_data['Daily Return'])

    return annualized_election_volatility, annualized_non_election_volatility, lev_stat, p_value

# %%
for x in range(1,13):
    for y in range(1,13):
        _, _, _, p_value = vol_difference_test(x, y, "GSPC.csv")
        print("Election Period: " + str(x) + " months before, " + str(y) + " months after. P-value: " + str(p_value))
# Out:
# Election Period: 1 months before, 1 months after. P-value: 5.25508238558292e-08
# Election Period: 1 months before, 2 months after. P-value: 1.7662413134182485e-05
# Election Period: 1 months before, 3 months after. P-value: 0.011230152196265589
# Election Period: 1 months before, 4 months after. P-value: 0.028811292401368413
# Election Period: 1 months before, 5 months after. P-value: 0.011855463374636008
# Election Period: 1 months before, 6 months after. P-value: 0.046066581906858986
# Election Period: 1 months before, 7 months after. P-value: 0.3163652722682728
# Election Period: 1 months before, 8 months after. P-value: 0.8454993467440793
# Election Period: 1 months before, 9 months after. P-value: 0.09208914114946472
# Election Period: 1 months before, 10 months after. P-value: 0.004893921549387352
# Election Period: 1 months before, 11 months after. P-value: 0.000919656448370338
# Election Period: 1 months before, 12 months after. P-value: 0.00042874496813348267
# Election Period: 2 months before, 1 months after. P-value: 1.8817471372683968e-07
# Election Period: 2 months before, 2 months after. P-value: 1.1699639323258925e-05
# Election Period: 2 months before, 3 months after. P-value: 0.004135987585985507
# Election Period: 2 months before, 4 months after. P-value: 0.010740018473294474
# Election Period: 2 months before, 5 months after. P-value: 0.004286985041876881
# Election Period: 2 months before, 6 months after. P-value: 0.01816848836148032
# Election Period: 2 months before, 7 months after. P-value: 0.15863228791539452
# Election Period: 2 months before, 8 months after. P-value: 0.8019668122515305
# Election Period: 2 months before, 9 months after. P-value: 0.22930040233074533
# Election Period: 2 months before, 10 months after. P-value: 0.02042565116135581
# Election Period: 2 months before, 11 months after. P-value: 0.004738082741527337
# Election Period: 2 months before, 12 months after. P-value: 0.002293895935558993
# Election Period: 3 months before, 1 months after. P-value: 0.004942887600938117
# Election Period: 3 months before, 2 months after. P-value: 0.018350385361565122
# Election Period: 3 months before, 3 months after. P-value: 0.23665857074578703
# Election Period: 3 months before, 4 months after. P-value: 0.31325595091794023
# Election Period: 3 months before, 5 months after. P-value: 0.16157366525642633
# Election Period: 3 months before, 6 months after. P-value: 0.3126090975623355
# Election Period: 3 months before, 7 months after. P-value: 0.8702061489108398
# Election Period: 3 months before, 8 months after. P-value: 0.3647932998939417
# Election Period: 3 months before, 9 months after. P-value: 0.022771083529029453
# Election Period: 3 months before, 10 months after. P-value: 0.0008469368974563869
# Election Period: 3 months before, 11 months after. P-value: 0.0001359931776846283
# Election Period: 3 months before, 12 months after. P-value: 5.774380604674476e-05
# Election Period: 4 months before, 1 months after. P-value: 0.0612676276079991
# Election Period: 4 months before, 2 months after. P-value: 0.12189417921896509
# Election Period: 4 months before, 3 months after. P-value: 0.6049374935361872
# Election Period: 4 months before, 4 months after. P-value: 0.6957685968362948
# Election Period: 4 months before, 5 months after. P-value: 0.42362411482154494
# Election Period: 4 months before, 6 months after. P-value: 0.6501342071235854
# Election Period: 4 months before, 7 months after. P-value: 0.732787646976051
# Election Period: 4 months before, 8 months after. P-value: 0.17238477927758358
# Election Period: 4 months before, 9 months after. P-value: 0.007107780134523401
# Election Period: 4 months before, 10 months after. P-value: 0.00019599184404203032
# Election Period: 4 months before, 11 months after. P-value: 2.750909554986555e-05
# Election Period: 4 months before, 12 months after. P-value: 1.0921025219710139e-05
# Election Period: 5 months before, 1 months after. P-value: 0.09540204915218012
# Election Period: 5 months before, 2 months after. P-value: 0.16451672307423934
# Election Period: 5 months before, 3 months after. P-value: 0.662874819557262
# Election Period: 5 months before, 4 months after. P-value: 0.7479161230091637
# Election Period: 5 months before, 5 months after. P-value: 0.4724032443759464
# Election Period: 5 months before, 6 months after. P-value: 0.6965343467158682
# Election Period: 5 months before, 7 months after. P-value: 0.7061736051306371
# Election Period: 5 months before, 8 months after. P-value: 0.16980884229969556
# Election Period: 5 months before, 9 months after. P-value: 0.007538758012039586
# Election Period: 5 months before, 10 months after. P-value: 0.00022338187226130508
# Election Period: 5 months before, 11 months after. P-value: 3.1849162246297424e-05
# Election Period: 5 months before, 12 months after. P-value: 1.2321977246417216e-05
# Election Period: 6 months before, 1 months after. P-value: 0.18072408971062712
# Election Period: 6 months before, 2 months after. P-value: 0.2703636307366756
# Election Period: 6 months before, 3 months after. P-value: 0.8327840355554045
# Election Period: 6 months before, 4 months after. P-value: 0.9112448839591772
# Election Period: 6 months before, 5 months after. P-value: 0.6131677624902223
# Election Period: 6 months before, 6 months after. P-value: 0.8461278939963566
# Election Period: 6 months before, 7 months after. P-value: 0.5841433430415415
# Election Period: 6 months before, 8 months after. P-value: 0.12916345477914168
# Election Period: 6 months before, 9 months after. P-value: 0.005230940316782055
# Election Period: 6 months before, 10 months after. P-value: 0.00014604899597828668
# Election Period: 6 months before, 11 months after. P-value: 2.0002787192041375e-05
# Election Period: 6 months before, 12 months after. P-value: 7.4099075068242316e-06
# Election Period: 7 months before, 1 months after. P-value: 0.07433313381908105
# Election Period: 7 months before, 2 months after. P-value: 0.12203154437779813
# Election Period: 7 months before, 3 months after. P-value: 0.4996401834860559
# Election Period: 7 months before, 4 months after. P-value: 0.5720517566452192
# Election Period: 7 months before, 5 months after. P-value: 0.3502179642246429
# Election Period: 7 months before, 6 months after. P-value: 0.5346632279712664
# Election Period: 7 months before, 7 months after. P-value: 0.9092985511196572
# Election Period: 7 months before, 8 months after. P-value: 0.28249107361746006
# Election Period: 7 months before, 9 months after. P-value: 0.019312722424320094
# Election Period: 7 months before, 10 months after. P-value: 0.0008280144337712704
# Election Period: 7 months before, 11 months after. P-value: 0.00013546380399973452
# Election Period: 7 months before, 12 months after. P-value: 5.243718178219652e-05
# Election Period: 8 months before, 1 months after. P-value: 5.440071980187102e-06
# Election Period: 8 months before, 2 months after. P-value: 2.3587383887035295e-05
# Election Period: 8 months before, 3 months after. P-value: 0.0009708289222089379
# Election Period: 8 months before, 4 months after. P-value: 0.0017854929550013671
# Election Period: 8 months before, 5 months after. P-value: 0.0006372625451852422
# Election Period: 8 months before, 6 months after. P-value: 0.002232263162618287
# Election Period: 8 months before, 7 months after. P-value: 0.02204359466233162
# Election Period: 8 months before, 8 months after. P-value: 0.19147449140838207
# Election Period: 8 months before, 9 months after. P-value: 0.9804765411809393
# Election Period: 8 months before, 10 months after. P-value: 0.3159636716566583
# Election Period: 8 months before, 11 months after. P-value: 0.13384655157411962
# Election Period: 8 months before, 12 months after. P-value: 0.07916555714177381
# Election Period: 9 months before, 1 months after. P-value: 3.315278323793758e-06
# Election Period: 9 months before, 2 months after. P-value: 1.3419772922234895e-05
# Election Period: 9 months before, 3 months after. P-value: 0.0005400128959405766
# Election Period: 9 months before, 4 months after. P-value: 0.0009875407061399153
# Election Period: 9 months before, 5 months after. P-value: 0.0003390158357605395
# Election Period: 9 months before, 6 months after. P-value: 0.0012090915397664189
# Election Period: 9 months before, 7 months after. P-value: 0.012959911932754482
# Election Period: 9 months before, 8 months after. P-value: 0.1292017556547582
# Election Period: 9 months before, 9 months after. P-value: 0.8020030463653168
# Election Period: 9 months before, 10 months after. P-value: 0.4422001554663718
# Election Period: 9 months before, 11 months after. P-value: 0.20626255852252043
# Election Period: 9 months before, 12 months after. P-value: 0.12772353266375072
# Election Period: 10 months before, 1 months after. P-value: 5.2691276599670395e-06
# Election Period: 10 months before, 2 months after. P-value: 1.8532190657790823e-05
# Election Period: 10 months before, 3 months after. P-value: 0.0006123439612712639
# Election Period: 10 months before, 4 months after. P-value: 0.0010645392207041917
# Election Period: 10 months before, 5 months after. P-value: 0.0003630407731702053
# Election Period: 10 months before, 6 months after. P-value: 0.0012279469098675374
# Election Period: 10 months before, 7 months after. P-value: 0.012485904435660042
# Election Period: 10 months before, 8 months after. P-value: 0.12178795969809322
# Election Period: 10 months before, 9 months after. P-value: 0.7670783354459452
# Election Period: 10 months before, 10 months after. P-value: 0.47528498906877914
# Election Period: 10 months before, 11 months after. P-value: 0.22735345273599292
# Election Period: 10 months before, 12 months after. P-value: 0.14217002774165766
# Election Period: 11 months before, 1 months after. P-value: 1.8601468477653758e-05
# Election Period: 11 months before, 2 months after. P-value: 5.445924714354739e-05
# Election Period: 11 months before, 3 months after. P-value: 0.0012995737219289548
# Election Period: 11 months before, 4 months after. P-value: 0.0020837443050035686
# Election Period: 11 months before, 5 months after. P-value: 0.0007313046154869627
# Election Period: 11 months before, 6 months after. P-value: 0.002223904447830033
# Election Period: 11 months before, 7 months after. P-value: 0.01917317528906106
# Election Period: 11 months before, 8 months after. P-value: 0.15913260386189867
# Election Period: 11 months before, 9 months after. P-value: 0.8642021819471215
# Election Period: 11 months before, 10 months after. P-value: 0.4063150539601187
# Election Period: 11 months before, 11 months after. P-value: 0.18634679679921762
# Election Period: 11 months before, 12 months after. P-value: 0.11345470826422138
# Election Period: 12 months before, 1 months after. P-value: 8.930445343004427e-06
# Election Period: 12 months before, 2 months after. P-value: 2.5752328959623664e-05
# Election Period: 12 months before, 3 months after. P-value: 0.0006492326573660737
# Election Period: 12 months before, 4 months after. P-value: 0.001046553894121395
# Election Period: 12 months before, 5 months after. P-value: 0.00034854125711950116
# Election Period: 12 months before, 6 months after. P-value: 0.0010956905943017056
# Election Period: 12 months before, 7 months after. P-value: 0.010500768986108671
# Election Period: 12 months before, 8 months after. P-value: 0.10207675882948014
# Election Period: 12 months before, 9 months after. P-value: 0.6839598593130295
# Election Period: 12 months before, 10 months after. P-value: 0.5550792451542035
# Election Period: 12 months before, 11 months after. P-value: 0.27953931708387547
# Election Period: 12 months before, 12 months after. P-value: 0.17861374844313446
